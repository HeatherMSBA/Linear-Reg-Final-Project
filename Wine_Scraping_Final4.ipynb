# %% [markdown]
# # Wine Scraping with BeautifulSoup & Selenium - PAGE 4

# %%
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup as bs
import html.parser
import time
import locale
from tqdm import tqdm
import requests
import re
import html.parser
from tqdm import tqdm
# for i in tqdm(range(100)):

# %%
driver = webdriver.Chrome(executable_path='chromedriver.exe')

# %%
url = 'https://www.totalwine.com/wine/red-wine/c/000009?&page=4&pageSize=120&ratingsource=Wine%20Advocate&aty=1,1,0,1'
driver.get(url)
time.sleep(2)

# %%
pageonesoup = bs(driver.page_source)

# %%
list_links = [link['href'] for link in pageonesoup.find(class_="grid__1eZnNfL-").find_all('a')]
len(list_links)
#triple reference for the 120 wines on the webpage
# Out:
# 360

# %%
list_links = list(set([link.split('&tab')[0] for link in list_links]))

# %%
list_links = ["https://www.totalwine.com"+link for link in list_links]

# %%
#need to sort list in place so I can pick up where I left off if site crashes
list_links.sort()

# %%
len(list_links)
# Out:
# 120

# %%
driver.close()

# %%
#define 10 helper functions for handling sale price and feature nulls
def find_price(soup):
    try:
        wineprice = newsoup.find(id="edlpPrice").text.strip("$")
    except:
        wineprice = newsoup.find(attrs={"data-at":"product-mix6price-text"}).text.strip("$")
    return wineprice

def find_countrystate(soup):
    try:
        winecountrystate = newsoup.find(text='COUNTRY / STATE').findNext().text
    except:
        winecountrystate = ''
    return winecountrystate

def find_region(soup):
    try:
        wineregion = newsoup.find(text='REGION').findNext().text
    except:
        wineregion = ''
    return wineregion

def find_appellation(soup):
    try:
        wineappellation = newsoup.find(text='APPELLATION').findNext().text
    except:
        wineappellation = ''
    return wineappellation

def find_varietal(soup):
    try:
        winevarietal = newsoup.find(text='VARIETAL').findNext().text
    except:
        winevarietal = ''
    return winevarietal

def find_style(soup):
    try:
        winestyle = newsoup.find(text='STYLE').findNext().text
    except:
        winestyle = ''
    return winestyle

def find_abv(soup):
    try:
        wineabv = newsoup.find(text='ABV').findNext().text.strip("%")
    except:
        wineabv = ''
    return wineabv

def find_taste(soup):
    try:
        winetaste = newsoup.find(text='TASTE').findNext().text
    except:
        winetaste = ''
    return winetaste

def find_body(soup):
    try:
        winebody = newsoup.find(text='BODY').findNext().text
    except:
        winebody = ''
    return winebody

def find_avgrating(soup):
    try:
        customeravgrating = newsoup.find(class_='bv_avgRating_component_container notranslate').text
    except:
        customeravgrating = ''
    return customeravgrating

# %%
#define function used to update list of dictionaries (1 dictionary per product page)
def update_list_w_dict(soup):
    headers = ['price','name','brand','country_state','region','appellation','varietal','style','abv','taste','body',
           'wine_adv_rating','customer_avg_rating','customer_total_ratings']
    product_dict = dict(zip(headers, [wineprice, winename, winebrand, winecountrystate, wineregion, wineappellation,
                                  winevarietal, winestyle, wineabv, winetaste, winebody, warating, customeravgrating,
                                  customertotalratings]))
    product_data.append(product_dict)
    return product_data

# %%
#product data needs to be established as empty list, will be appended with dictionaries & reset after each section is run
product_data=[]
#GROUP 1

# %%
#0
url = list_links[0]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(2,4.5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#1
url = list_links[1]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,4))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#2
url = list_links[2]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(2,4.5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#3
url = list_links[3]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,4))
driver.get(url)
time.sleep(np.random.uniform(3,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#4
url = list_links[4]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,4))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
len(product_data)
# Out:
# 5

# %%
df = pd.DataFrame(product_data)
df.to_csv('wine_data1.csv', mode='a', header=False)

# %%
product_data=[]
#GROUP 2

# %%
#0
url = list_links[5]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(3,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(3,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#1
url = list_links[6]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#2
url = list_links[7]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#3
url = list_links[8]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(3,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#4
url = list_links[9]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,4))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
len(product_data)
# Out:
# 5

# %%
df = pd.DataFrame(product_data)
df.to_csv('wine_data1.csv', mode='a', header=False)

# %%
product_data=[]
#GROUP 3

# %%
#0
url = list_links[10]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#1
url = list_links[11]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,4))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#2
url = list_links[12]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#3
url = list_links[13]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#4
url = list_links[14]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,5))
driver.get(url)
time.sleep(np.random.uniform(3,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
len(product_data)
# Out:
# 5

# %%
df = pd.DataFrame(product_data)
df.to_csv('wine_data1.csv', mode='a', header=False)

# %%
product_data=[]
#GROUP 4

# %%
#0
url = list_links[15]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(2,4.5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#1
url = list_links[16]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(2,4.5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#2
url = list_links[17]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,4))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#3
url = list_links[18]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(3,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(3,6))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#4
url = list_links[19]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,5))
driver.get(url)
time.sleep(np.random.uniform(2,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
len(product_data)
# Out:
# 5

# %%
df = pd.DataFrame(product_data)
df.to_csv('wine_data1.csv', mode='a', header=False)

# %%
product_data=[]
#GROUP 5

# %%
#0
url = list_links[20]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,6))
driver.get(url)
time.sleep(np.random.uniform(2,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#1
url = list_links[21]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(3,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#2
url = list_links[22]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#3
url = list_links[23]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#4
url = list_links[24]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
len(product_data)
# Out:
# 5

# %%
df = pd.DataFrame(product_data)
df.to_csv('wine_data1.csv', mode='a', header=False)

# %%
product_data=[]
#GROUP 6

# %%
#0
url = list_links[25]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(2,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(3,6))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#1
url = list_links[26]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(3,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#2
url = list_links[27]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.6,5))
driver.get(url)
time.sleep(np.random.uniform(2,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#3
url = list_links[28]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(2,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#4
url = list_links[29]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,3))

# %%
len(product_data)
# Out:
# 5

# %%
df = pd.DataFrame(product_data)
df.to_csv('wine_data1.csv', mode='a', header=False)

# %%
product_data=[]
#GROUP 7

# %%
#0
url = list_links[30]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(3,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#1
url = list_links[31]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,4))
driver.get(url)
time.sleep(np.random.uniform(3,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#2
url = list_links[32]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,4))
driver.get(url)
time.sleep(np.random.uniform(3,5.7))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#3
url = list_links[33]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,4))
driver.get(url)
time.sleep(np.random.uniform(3,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#4
url = list_links[34]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,4))
driver.get(url)
time.sleep(np.random.uniform(3,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
len(product_data)
# Out:
# 5

# %%
df = pd.DataFrame(product_data)
df.to_csv('wine_data1.csv', mode='a', header=False)

# %%
product_data=[]
#GROUP 8

# %%
#0
url = list_links[35]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#1
url = list_links[36]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,4))
driver.get(url)
time.sleep(np.random.uniform(3,5.4))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#2
url = list_links[37]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,4.1))
driver.get(url)
time.sleep(np.random.uniform(3,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#3
url = list_links[38]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,4))
driver.get(url)
time.sleep(np.random.uniform(2,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#4
url = list_links[39]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,4))
driver.get(url)
time.sleep(np.random.uniform(2,4.5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
len(product_data)
# Out:
# 5

# %%
df = pd.DataFrame(product_data)
df.to_csv('wine_data1.csv', mode='a', header=False)

# %%
product_data=[]
#GROUP 9

# %%
#0
url = list_links[40]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(2,4.5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#1
url = list_links[41]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(3,5))
driver.get(url)
time.sleep(np.random.uniform(2,4.5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#2
url = list_links[42]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#3
url = list_links[43]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#4
url = list_links[44]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.1,4.7))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
len(product_data)
# Out:
# 5

# %%
df = pd.DataFrame(product_data)
df.to_csv('wine_data1.csv', mode='a', header=False)

# %%
product_data=[]
#GROUP 10

# %%
#0
url = list_links[45]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(2,4.5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#1
url = list_links[46]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#2
url = list_links[47]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,4))
driver.get(url)
time.sleep(np.random.uniform(3.2,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#3
url = list_links[48]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(2,4.5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#4
url = list_links[49]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,4.4))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
len(product_data)
# Out:
# 5

# %%
df = pd.DataFrame(product_data)
df.to_csv('wine_data1.csv', mode='a', header=False)

# %%
product_data=[]
#GROUP 11

# %%
#0
url = list_links[50]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(2,4.5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(3,5.6))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#1
url = list_links[51]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#2
url = list_links[52]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(2,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#3
url = list_links[53]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5.1))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#4
url = list_links[54]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,4))
driver.get(url)
time.sleep(np.random.uniform(3,5.9))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
len(product_data)
# Out:
# 5

# %%
df = pd.DataFrame(product_data)
df.to_csv('wine_data1.csv', mode='a', header=False)

# %%
product_data=[]
#GROUP 12

# %%
#0
url = list_links[55]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,4.5))
driver.get(url)
time.sleep(np.random.uniform(3,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#1
url = list_links[56]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(2,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#2
url = list_links[57]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(3,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#3
url = list_links[58]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(3,5.8))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#4
url = list_links[59]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,4))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
len(product_data)
# Out:
# 5

# %%
df = pd.DataFrame(product_data)
df.to_csv('wine_data1.csv', mode='a', header=False)

# %%
product_data=[]
#GROUP 13

# %%
#0
url = list_links[60]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(2,4.5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#1
url = list_links[61]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(3,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#2
url = list_links[62]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#3
url = list_links[63]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#4
url = list_links[64]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
len(product_data)
# Out:
# 5

# %%
df = pd.DataFrame(product_data)
df.to_csv('wine_data1.csv', mode='a', header=False)

# %%
product_data=[]
#GROUP 14

# %%
#0
url = list_links[65]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(2,4.5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#1
url = list_links[66]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(3,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#2
url = list_links[67]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(3,5.8))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#3
url = list_links[68]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(3,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(3,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#4
url = list_links[69]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(3,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(3,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
len(product_data)
# Out:
# 5

# %%
df = pd.DataFrame(product_data)
df.to_csv('wine_data1.csv', mode='a', header=False)

# %%
product_data=[]
#GROUP 15

# %%
#0
url = list_links[70]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,4))
driver.get(url)
time.sleep(np.random.uniform(2,4.5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#1
url = list_links[71]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(2,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#2
url = list_links[72]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(3,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#3
url = list_links[73]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(3,5.5))
driver.get(url)
time.sleep(np.random.uniform(3,5.6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#4
url = list_links[74]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(3,6))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
len(product_data)
# Out:
# 5

# %%
df = pd.DataFrame(product_data)
df.to_csv('wine_data1.csv', mode='a', header=False)

# %%
product_data=[]
#GROUP 16

# %%
#0
url = list_links[75]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,4))
driver.get(url)
time.sleep(np.random.uniform(2,4.95))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#1
url = list_links[76]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(3,5.2))
driver.get(url)
time.sleep(np.random.uniform(2.7,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#2
url = list_links[77]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5.2))
driver.get(url)
time.sleep(np.random.uniform(2,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#3
url = list_links[78]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(3,6))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#4
url = list_links[79]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5.5))
driver.get(url)
time.sleep(np.random.uniform(2,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
len(product_data)
# Out:
# 5

# %%
df = pd.DataFrame(product_data)
df.to_csv('wine_data1.csv', mode='a', header=False)

# %%
product_data=[]
#GROUP 17

# %%
#0
url = list_links[80]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,4))
driver.get(url)
time.sleep(np.random.uniform(3,5.6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#1
url = list_links[81]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#2
url = list_links[82]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#3
url = list_links[83]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(3,5.1))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#4
url = list_links[84]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.95,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
len(product_data)
# Out:
# 5

# %%
df = pd.DataFrame(product_data)
df.to_csv('wine_data1.csv', mode='a', header=False)

# %%
product_data=[]
#GROUP 18

# %%
#0
url = list_links[85]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,4))
driver.get(url)
time.sleep(np.random.uniform(3,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#1
url = list_links[86]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#2
url = list_links[87]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.4,5.4))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#3
url = list_links[88]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.71,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#4
url = list_links[89]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.65,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
len(product_data)
# Out:
# 5

# %%
df = pd.DataFrame(product_data)
df.to_csv('wine_data1.csv', mode='a', header=False)

# %%
product_data=[]
#GROUP 19

# %%
#0
url = list_links[90]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(2,4.95))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#1
url = list_links[91]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(2,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#2
url = list_links[92]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(3.5,5))
driver.get(url)
time.sleep(np.random.uniform(2,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#3
url = list_links[93]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.75,5))
driver.get(url)
time.sleep(np.random.uniform(3.2,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#4
url = list_links[94]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,4))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
len(product_data)
# Out:
# 5

# %%
df = pd.DataFrame(product_data)
df.to_csv('wine_data1.csv', mode='a', header=False)

# %%
product_data=[]
#GROUP 20

# %%
#0
url = list_links[95]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,4))
driver.get(url)
time.sleep(np.random.uniform(2,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#1
url = list_links[96]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(2.6,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#2
url = list_links[97]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#3
url = list_links[98]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.6,4.9))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#4
url = list_links[99]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(3.2,5.2))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
len(product_data)
# Out:
# 5

# %%
df = pd.DataFrame(product_data)
df.to_csv('wine_data1.csv', mode='a', header=False)

# %%
product_data=[]
#GROUP 21

# %%
#0
url = list_links[100]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,4.75))
driver.get(url)
time.sleep(np.random.uniform(2,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#1
url = list_links[101]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,5))
driver.get(url)
time.sleep(np.random.uniform(2,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#2
url = list_links[102]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,5.4))
driver.get(url)
time.sleep(np.random.uniform(2,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#3
url = list_links[103]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#4
url = list_links[104]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(3.2,6))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2.2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
len(product_data)
# Out:
# 1

# %%
df = pd.DataFrame(product_data)
df.to_csv('wine_data1.csv', mode='a', header=False)

# %%
product_data=[]
#GROUP 22

# %%
#0
url = list_links[105]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,4))
driver.get(url)
time.sleep(np.random.uniform(2,4.5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#1
url = list_links[106]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#2
url = list_links[107]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(2,4.5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#3
url = list_links[108]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.75,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#4
url = list_links[109]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(3,5.5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2.2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
len(product_data)
# Out:
# 5

# %%
df = pd.DataFrame(product_data)
df.to_csv('wine_data1.csv', mode='a', header=False)

# %%
product_data=[]
#GROUP 23

# %%
#0
url = list_links[110]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2,4.5))
driver.get(url)
time.sleep(np.random.uniform(2,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#1
url = list_links[111]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(3.2,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#2
url = list_links[112]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#3
url = list_links[113]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(3,6))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2.4,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#4
url = list_links[114]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
len(product_data)
# Out:
# 5

# %%
df = pd.DataFrame(product_data)
df.to_csv('wine_data1.csv', mode='a', header=False)

# %%
product_data=[]
#GROUP 24

# %%
#0
url = list_links[115]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(2,4.5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#1
url = list_links[116]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.75,5))
driver.get(url)
time.sleep(np.random.uniform(2,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#2
url = list_links[117]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.85,5))
driver.get(url)
time.sleep(np.random.uniform(3,6))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#3
url = list_links[118]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(3,5.5))
driver.get(url)
time.sleep(np.random.uniform(2,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
#4
url = list_links[119]
driver = webdriver.Chrome(executable_path='chromedriver.exe')
time.sleep(np.random.uniform(2.5,5))
driver.get(url)
time.sleep(np.random.uniform(2.7,5))
newsoup = bs(driver.page_source)
time.sleep(np.random.uniform(2,4.5))
wineprice = find_price(newsoup)
winename = newsoup.find(attrs={"data-at":"product-breadcrumb-productname-text"}).text
winebrand = newsoup.find(text='BRAND').findNext().text
winecountrystate = find_countrystate(newsoup)
wineregion = find_region(newsoup)
wineappellation = find_appellation(newsoup)
winevarietal = find_varietal(newsoup)
winestyle = find_style(newsoup)
wineabv = find_abv(newsoup)
winetaste = find_taste(newsoup)
winebody = find_body(newsoup)
warating = newsoup.find(attrs={"data-at":"product-badge-container"}).text
customeravgrating = find_avgrating(newsoup)
customertotalratings = newsoup.find(class_="bv_numReviews_text").text.strip("()")
update_list_w_dict(newsoup)
driver.quit()
time.sleep(np.random.uniform(2,4))

# %%
len(product_data)
# Out:
# 5

# %%
df = pd.DataFrame(product_data)
df.to_csv('wine_data1.csv', mode='a', header=False)
